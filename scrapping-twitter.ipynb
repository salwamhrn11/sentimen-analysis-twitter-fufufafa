# %%
twitter_auth_token = "fc13bdda9d49f47a244e98f95be492af2c6c5f3a"

# %%
# Crawl Data

filename = 'scrapping-twitter-1.csv'
search_keyword = 'fufufafa since:2024-06-01 until:2024-09-01 lang:id'
limit = 1000

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# Found existing file ./tweets-data/scrapping-twitter-1.csv, renaming to ./tweets-data/scrapping-twitter-1.old.csv
#
# Filling in keywords: fufufafa since:2024-06-01 until:2024-09-01 lang:id
#
#
# -- Scrolling... (1)
#
# Your tweets saved to: c:\Users\User\documents salwa\portofolio\sentiment-analysis-twitter-fafafufu\tweets-data\scrapping-twitter-1.csv
# Total tweets saved: 18
#
# -- Scrolling... (1)
#
# Your tweets saved to: c:\Users\User\documents salwa\portofolio\sentiment-analysis-twitter-fafafufu\tweets-data\scrapping-twitter-1.csv
# Total tweets saved: 29
#
# ...

# %%
# Cek jumlah data yang didapatkan
import pandas as pd

df = pd.read_csv('tweets-data/scrapping-twitter-1.csv')
num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")
# Out:
# Jumlah tweet dalam dataframe adalah 410.
